# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.2-cp36-cp36m-win_amd64.whl (6.8 MB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\juan fracisco\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\juan fracisco\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\juan fracisco\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.5.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1317 sha256=9e1757af58cbedc33e6a44f3d1f428f5a07894a16b03407599d7a23e2a56b9a4
#   Stored in directory: c:\users\juan fracisco\appdata\local\pip\cache\wheels\23\9d\42\5ec745cbbb17517000a53cecc49d6a865450d1f5cb16dc8a9c
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scikit-learn, sklearn
# Successfully installed scikit-learn-0.24.2 sklearn-0.0 threadpoolctl-2.2.0

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\juan fracisco\anaconda3\envs\pythondata\lib\site-packages (1.0.1)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFECV
import joblib

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['names', 'of', 'selected', 'features', 'here']]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# This part assigns the X and y values

X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]

# Next step is to split the data into training and testing groups

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6080              1              0              0              0   12.496435
# 3001              0              0              0              0   11.615625
# 570               0              1              0              0   10.980246
# 4897              1              0              0              0  466.908240
# 625               0              1              1              1    1.061933
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6080     2.213000e-04    -2.213000e-04   132.035800          0.014300
# 3001     1.528000e-04    -1.528000e-04   131.968430          0.008230
# 570      6.930000e-07    -6.930000e-07   137.137607          0.000053
# 4897     1.194000e-02    -1.194000e-02   136.373100          0.019000
# 625      1.250000e-06    -1.250000e-06   133.850441          0.000978
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6080         -0.014300  ...            -286      3.805           0.390
# 3001         -0.008230  ...             -72      4.083           0.368
# 570          -0.000053  ...            -159      4.462           0.098
# 4897         -0.019000  ...            -146      4.456           0.102
# 625          -0.000978  ...            -167      3.975           0.259
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6080          -0.130     2.730          0.535         -1.248  289.23080
# 3001          -0.092     1.453          0.218         -0.510  293.52756
# 570           -0.182     0.897          0.238         -0.119  282.79764
# 4897          -0.361     0.867          0.448         -0.103  297.65436
# 625           -0.111     1.851          0.383         -0.575  288.90253
#
#             dec  koi_kepmag
# 6080  44.412483      13.054
# 3001  41.111439      15.162
# 570   43.578129      14.212
# 4897  43.178551      15.202
# 625   44.632992      12.953
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data

# X values

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
model2 = LogisticRegression(solver='newton-cg', multi_class='auto')
model2.fit(X_train_scaled, y_train)
print(f"Training Data Score: {model2.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model2.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8550448216669846
# Testing Data Score: 0.8621281464530892

# %%
# I think I needed to do this first before choosing my features.

feature_names = X.columns.tolist()
selector = RFECV(estimator=model2, cv=5, step=1)
fitter = selector.fit(X_train_scaled, y_train)

# %%
# visualize features

preSelected_features = sorted(zip(selector.ranking_, feature_names))
preSelected_features
# Out:
# [(1, 'dec'),
#  (1, 'koi_depth'),
#  (1, 'koi_duration'),
#  (1, 'koi_duration_err1'),
#  (1, 'koi_duration_err2'),
#  (1, 'koi_fpflag_co'),
#  (1, 'koi_fpflag_ec'),
#  (1, 'koi_fpflag_nt'),
#  (1, 'koi_fpflag_ss'),
#  (1, 'koi_impact'),
#  (1, 'koi_impact_err1'),
#  (1, 'koi_impact_err2'),
#  (1, 'koi_model_snr'),
#  (1, 'koi_period'),
#  (1, 'koi_period_err1'),
#  (1, 'koi_period_err2'),
#  (1, 'koi_slogg'),
#  (1, 'koi_slogg_err1'),
#  (1, 'koi_slogg_err2'),
#  (1, 'koi_srad'),
#  (1, 'koi_srad_err1'),
#  (1, 'koi_srad_err2'),
#  (1, 'koi_steff'),
#  (1, 'koi_steff_err1'),
#  (1, 'koi_steff_err2'),
#  (1, 'koi_tce_plnt_num'),
#  (1, 'koi_teq'),
#  (1, 'koi_time0bk'),
#  (1, 'koi_time0bk_err1'),
#  (1, 'koi_time0bk_err2'),
#  (1, 'ra'),
#  (2, 'koi_kepmag'),
#  (3, 'koi_insol_err1'),
#  (4, 'koi_prad_err1'),
#  (5, 'koi_prad'),
#  (6, 'koi_insol'),
#  (7, 'koi_insol_err2'),
#  (8, 'koi_prad_err2'),
#  (9, 'koi_depth_err2'),
#  (10, 'koi_depth_err1')]

# %%
selected_features = []
for tup in preSelected_features:
    if tup[0] < 17:
        selected_features.append(tup[1])

selected_features
# Out:
# ['dec',
#  'koi_depth',
#  'koi_duration',
#  'koi_duration_err1',
#  'koi_duration_err2',
#  'koi_fpflag_co',
#  'koi_fpflag_ec',
#  'koi_fpflag_nt',
#  'koi_fpflag_ss',
#  'koi_impact',
#  'koi_impact_err1',
#  'koi_impact_err2',
#  'koi_model_snr',
#  'koi_period',
#  'koi_period_err1',
#  'koi_period_err2',
#  'koi_slogg',
#  'koi_slogg_err1',
#  'koi_slogg_err2',
#  'koi_srad',
#  'koi_srad_err1',
#  'koi_srad_err2',
#  'koi_steff',
#  'koi_steff_err1',
#  'koi_steff_err2',
#  'koi_tce_plnt_num',
#  'koi_teq',
#  'koi_time0bk',
#  'koi_time0bk_err1',
#  'koi_time0bk_err2',
#  'ra',
#  'koi_kepmag',
#  'koi_insol_err1',
#  'koi_prad_err1',
#  'koi_prad',
#  'koi_insol',
#  'koi_insol_err2',
#  'koi_prad_err2',
#  'koi_depth_err2',
#  'koi_depth_err1']

# %%
# Use new data for all subsequent models

X_train_select = X_train[selected_features]
X_test_select = X_test[selected_features]

X_scaler = MinMaxScaler().fit(X_train_select)
X_train_scaled = X_scaler.transform(X_train_select)
X_test_scaled = X_scaler.transform(X_test_select)

## Train new model
model_2 = LogisticRegression(solver='newton-cg', multi_class='auto')
model_2.fit(X_train_scaled, y_train)

model_2_training_score = round(model_2.score(X_train_scaled, y_train)*100,3)
select_features_accuracy = round(model_2.score(X_test_scaled, y_test)*100,3)

print(f"Training Data Score: {model_2_training_score} %")
print(f"Testing Data Score: {select_features_accuracy} %")
# Out:
# Training Data Score: 85.504 %
# Testing Data Score: 86.213 %

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
model_3 = LogisticRegression(solver='newton-cg', multi_class='auto')

param_grid = {
    'C': np.logspace(0, 4, 10),
    'penalty': ['l2']
}
grid2 = GridSearchCV(model_3, param_grid, cv=5, verbose=0)

# %%
# Train the model with GridSearch. I think this is just fine
_ = grid2.fit(X_train_scaled, y_train)

# %%
print(grid2.best_params_)
print(grid2.best_score_)
# Out:
# {'C': 1291.5496650148827, 'penalty': 'l2'}
# 0.8842261623210763

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
